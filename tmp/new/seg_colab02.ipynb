# %% [markdown]
# # **To Do**

# %% [markdown]
# Go to File > Open in playground mode
#
# **!!! Change Runtime to GPU !!!**
#
# **Go to Runtime > Change runtime type > Hardware accelerator:GPU **
#
# To run, go Runtime> Restart and run all

# %%
# !git clone https://github.com/twpkevin06222/Liver-Segmentation-Project-.git medical_imaging
# Out:
# Cloning into 'medical_imaging'...
# remote: Enumerating objects: 527, done.
# remote: Total 527 (delta 0), reused 0 (delta 0), pack-reused 527
# Receiving objects: 100% (527/527), 290.95 MiB | 36.62 MiB/s, done.
# Resolving deltas: 100% (154/154), done.

# %%
# !pip install nibabel
# Out:
# Collecting nibabel
#   Downloading https://files.pythonhosted.org/packages/a4/63/aad4c6f6ffe3e23226f0905db5994e928e966267d2d191c39e96ddc40bcb/nibabel-2.3.1.tar.gz (4.2MB)
#     100% |████████████████████████████████| 4.2MB 5.6MB/s
# Building wheels for collected packages: nibabel
# done
#   Stored in directory: /root/.cache/pip/wheels/6d/50/60/a2fcafe72ababac5240b3df2ee903197bec24b74d75840153f
# Successfully built nibabel
# Installing collected packages: nibabel
# Successfully installed nibabel-2.3.1

# %% [markdown]
# # Imports

# %%
import h5py
import os
import cv2
from keras.layers import Input,Dense,Flatten,Dropout,merge,Reshape,Conv2D,MaxPooling2D,UpSampling2D,Conv2DTranspose
from keras.layers.normalization import BatchNormalization
from keras.models import Model,Sequential
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adadelta, RMSprop,SGD,Adam
from keras import regularizers
from keras import backend as K
import numpy as np
import scipy.misc
import numpy.random as rng
from PIL import Image, ImageDraw, ImageFont
from sklearn.utils import shuffle
import nibabel as nib #reading nifti images
import math
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
#from read_data import load_images
from keras.layers.merge import concatenate
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Dependencies

# %%
import tensorflow as tf
import keras
print('Tensorflow version:', tf.__version__)
print('Keras version:', keras.__version__)
# Out:
# Tensorflow version: 1.12.0
# Keras version: 2.2.4

# %% [markdown]
# ---

# %% [markdown]
# # Data Preprocessing
# Prepare data for input and data preprocessing

# %%
def three_to_two(path, label='FALSE'):
    ff = sorted(glob.glob(path))
    images =[]
    for f in range(len(ff)):
        a = nib.load(ff[f])
        a = a.get_data()
        for i in range(a.shape[2]):
            images.append(a[:,:,i])     
    images = np.asarray(images)
    #images = images.reshape(-1, 128,128, 1) # dimension to feed into the network
    return images

def min_max_norm(images):
    m = np.max(images)
    mi = np.min(images)
    images = (images - mi)/ (m - mi)
    return images

def label_outliers(img_labels):
    img_labels[img_labels>1]=1
    img_labels[img_labels<0]=0
    return img_labels

#Image for training 
images = three_to_two(path='medical_imaging/tmp/tmp_img/img_new/*')
x_data = min_max_norm(images)

#labels
img_labels = three_to_two(path='medical_imaging/tmp/tmp_img/img_new_label/*')
y_data = label_outliers(img_labels)

#Test Image
img_test = three_to_two(path='medical_imaging/tmp/tmp_img/test_img/*')
x_test = min_max_norm(img_test)

#Test Labels
label_test = three_to_two(path='medical_imaging/tmp/tmp_img/test_img_label/*')
y_test = label_outliers(label_test)

# %% [markdown]
# Plot data w.r.t labels

# %%
#show 1st 20 slices

for i in range(20):
    fig, ax = plt.subplots(1,4, figsize = (8,4))
    ax[0].imshow(x_data[i], cmap='gray')
    ax[1].imshow(y_data[i], cmap='gray')
    ax[2].imshow(x_test[i], cmap='gray')
    ax[3].imshow(y_test[i], cmap='gray')
    
plt.show()

# %% [markdown]
# Reshape input data to feed into the network with
# shape (depth*#image, width, height, channel)

# %%
x_data = x_data[:,:,:,np.newaxis] # same as reshape (-1,128,128,1)
y_data = y_data[:,:,:,np.newaxis]
x_test = x_test[:,:,:,np.newaxis]
y_test = y_test[:,:,:,np.newaxis]

print('Dimension for training data:', x_data.shape)
print('Dimension for training data labels:', y_data.shape)
print('Dimension for test data:', x_test.shape)
print('Dimension for test data labels:', y_test.shape)
# Out:
# Dimension for training data: (3036, 128, 128, 1)
# Dimension for training data labels: (3036, 128, 128, 1)
# Dimension for test data: (735, 128, 128, 1)
# Dimension for test data labels: (735, 128, 128, 1)

# %% [markdown]
# Split data: 80% Training, 20% Validation

# %%
from sklearn.utils import shuffle

#x_train, x_val, y_train, y_val = train_test_split(x_data, y_data, test_size = 0.2)
x_train, y_train = shuffle(x_data, y_data, random_state =42)
x_test, y_test = shuffle(x_test, y_test, random_state= 42)

# %% [markdown]
# Approximation of Dice Coefficient

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
input_layer = Input(shape=x_train.shape[1:]) #Input(shape = (x, y, inChannel))

# %% [markdown]
# ---

# %% [markdown]
# # Network Topology

# %% [markdown]
# Toy Model 01

# %%
def Unet_01(input_layer):
    c1 = Conv2D(filters=8, kernel_size=(3,3), activation='relu', padding='same')(input_layer)
    l = MaxPooling2D(strides=(2,2))(c1)
    c2 = Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same')(l)
    l = MaxPooling2D(strides=(2,2))(c2)
    c3 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(l)
    l = MaxPooling2D(strides=(2,2))(c3)
    c4 = Conv2D(filters=32, kernel_size=(1,1), activation='relu', padding='same')(l)
    l = concatenate([UpSampling2D(size=(2,2))(c4), c3], axis=-1)
    l = Conv2D(filters=32, kernel_size=(2,2), activation='relu', padding='same')(l)
    l = concatenate([UpSampling2D(size=(2,2))(l), c2], axis=-1)
    l = Conv2D(filters=24, kernel_size=(2,2), activation='relu', padding='same')(l)
    l = concatenate([UpSampling2D(size=(2,2))(l), c1], axis=-1)
    l = Conv2D(filters=16, kernel_size=(2,2), activation='relu', padding='same')(l)
    l = Conv2D(filters=64, kernel_size=(1,1), activation='relu')(l)
    l = Dropout(0.5)(l)
    output_layer = Conv2D(filters=1, kernel_size=(1,1), activation='sigmoid')(l)

    model = Model(input_layer, output_layer)
    return model

# %% [markdown]
# Toy Model 02

# %%
def Unet_02(input_layer, k_size=(3,3)):
    merge_axis = -1 # Feature maps are concatenated along last axis (for tf backend)
    conv1 = Conv2D(filters=32, kernel_size=k_size, padding='same', activation='relu')(input_layer)
    conv1 = Conv2D(filters=32, kernel_size=k_size, padding='same', activation='relu')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(pool1)
    conv2 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(pool2)
    conv3 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(pool3)
    conv4 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(pool4)

    up1 = UpSampling2D(size=(2, 2))(conv5)
    conv6 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(up1)
    conv6 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(conv6)
    merged1 = concatenate([conv4, conv6], axis=merge_axis)
    conv6 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(merged1)

    up2 = UpSampling2D(size=(2, 2))(conv6)
    conv7 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(up2)
    conv7 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(conv7)
    merged2 = concatenate([conv3, conv7], axis=merge_axis)
    conv7 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(merged2)

    up3 = UpSampling2D(size=(2, 2))(conv7)
    conv8 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(up3)
    conv8 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(conv8)
    merged3 = concatenate([conv2, conv8], axis=merge_axis)
    conv8 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(merged3)

    up4 = UpSampling2D(size=(2, 2))(conv8)
    conv9 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(up4)
    conv9 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(conv9)
    merged4 = concatenate([conv1, conv9], axis=merge_axis)
    conv9 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(merged4)
    
    conv10 = Conv2D(filters=1, kernel_size=k_size, padding='same', activation='sigmoid')(conv9)
    output_layer = conv10
    
    model = Model(input_layer, output_layer)
    return model

# %%
def Unet_03(input_layer, k_size=(3,3)):
    merge_axis = -1 # Feature maps are concatenated along last axis (for tf backend)
    conv1 = Conv2D(filters=32, kernel_size=k_size, padding='same', activation='relu')(input_layer)
    conv1 = Conv2D(filters=32, kernel_size=k_size, padding='same', activation='relu')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(pool1)
    conv2 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(pool2)
    conv3 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(pool3)
    conv4 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(pool4)

    up1 = UpSampling2D(size=(2, 2))(conv5)
    conv6 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(up1)
    conv6 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(conv6)
    merged1 = concatenate([conv4, conv6], axis=merge_axis)
    conv6 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(merged1)

    up2 = UpSampling2D(size=(2, 2))(conv6)
    conv7 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(up2)
    conv7 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(conv7)
    merged2 = concatenate([conv3, conv7], axis=merge_axis)
    conv7 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(merged2)

    up3 = UpSampling2D(size=(2, 2))(conv7)
    conv8 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(up3)
    conv8 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(conv8)
    merged3 = concatenate([conv2, conv8], axis=merge_axis)
    conv8 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(merged3)

    up4 = UpSampling2D(size=(2, 2))(conv8)
    conv9 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(up4)
    conv9 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(conv9)
    merged4 = concatenate([conv1, conv9], axis=merge_axis)
    conv9 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(merged4)
    
    drop = Dropout(0.5)(conv9)
    conv10 = Conv2D(filters=1, kernel_size=k_size, padding='same', activation='sigmoid')(drop)
    output_layer = conv10
    
    model = Model(input_layer, output_layer)
    return model

# %%
def Unet_04(input_layer, k_size=(3,3)):
    merge_axis = -1 # Feature maps are concatenated along last axis (for tf backend)
    conv1 = Conv2D(filters=32, kernel_size=k_size, padding='same', activation='relu')(input_layer)
    conv1 = Conv2D(filters=32, kernel_size=k_size, padding='same', activation='relu')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    pool1 = Dropout(0.2, seed=42)(pool1)
    
    conv2 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(pool1)
    conv2 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    pool2 = Dropout(0.5, seed=42)(pool2)
    
    conv3 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(pool2)
    conv3 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = Dropout(0.2, seed=42)(pool3)
    
    conv4 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(pool3)
    conv4 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    pool4 = Dropout(0.5, seed=42)(pool4)
    
    conv5 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(pool4)

    up1 = UpSampling2D(size=(2, 2))(conv5)
    conv6 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(up1)
    conv6 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(conv6)
    merged1 = concatenate([conv4, conv6], axis=merge_axis)
    conv6 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(merged1)

    up2 = UpSampling2D(size=(2, 2))(conv6)
    conv7 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(up2)
    conv7 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(conv7)
    merged2 = concatenate([conv3, conv7], axis=merge_axis)
    conv7 = Conv2D(filters=256, kernel_size=k_size, padding='same', activation='relu')(merged2)

    up3 = UpSampling2D(size=(2, 2))(conv7)
    conv8 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(up3)
    conv8 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(conv8)
    merged3 = concatenate([conv2, conv8], axis=merge_axis)
    conv8 = Conv2D(filters=128, kernel_size=k_size, padding='same', activation='relu')(merged3)

    up4 = UpSampling2D(size=(2, 2))(conv8)
    conv9 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(up4)
    conv9 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(conv9)
    merged4 = concatenate([conv1, conv9], axis=merge_axis)
    conv9 = Conv2D(filters=64, kernel_size=k_size, padding='same', activation='relu')(merged4)
    conv9 = Dropout(0.5, seed=42)(conv9)
    
    conv10 = Conv2D(filters=1, kernel_size=k_size, padding='same', activation='sigmoid')(conv9)
    output_layer = conv10
    
    model = Model(input_layer, output_layer)
    return model

# %% [markdown]
# Swtich for different network

# %%
#model = Unet_01(input_layer)
model = Unet_02(input_layer)
#model = Unet_03(input_layer)
#model = Unet_04(input_layer)

# %% [markdown]
# Data Augmentation

# %%
def my_generator(x_train, y_train, batch_size):
    data_generator = ImageDataGenerator(
            width_shift_range=0.1,
            height_shift_range=0.1,
            rotation_range=10,
            zoom_range=0.1).flow(x_train, x_train, batch_size, seed=42)
    mask_generator = ImageDataGenerator(
            width_shift_range=0.1,
            height_shift_range=0.1,
            rotation_range=10,
            zoom_range=0.1).flow(y_train, y_train, batch_size, seed=42)
    while True:
        x_batch, _ = data_generator.next()
        y_batch, _ = mask_generator.next()
        yield x_batch, y_batch

# %%
image_batch, mask_batch = next(my_generator(x_train, y_train, 8))
fix, ax = plt.subplots(8,2, figsize=(8,20))
for i in range(8):
    ax[i,0].imshow(image_batch[i,:,:,0], cmap='gray')
    ax[i,1].imshow(mask_batch[i,:,:,0], cmap='gray')
plt.show()

# %%
model.compile(optimizer=Adam(2e-4), loss= dice_coef_loss, metrics=[dice_coef])

# %% [markdown]
# Set checkpoint

# %%
from keras.callbacks import LearningRateScheduler
weight_saver = ModelCheckpoint('seg.h5', monitor='val_dice_coef', 
                                              save_best_only=True, save_weights_only=True)
annealer = LearningRateScheduler(lambda x: 1e-3 * 0.8 ** x)

# %% [markdown]
# Parameters

# %%
batch_size = 32
epochs = 50

# %%
from keras.callbacks import TensorBoard
import time

model_dir = 'logs/{}'.format(time.strftime("%H"+"%M"))
tensorboard = TensorBoard(log_dir= model_dir, histogram_freq=epochs, batch_size=batch_size, write_graph=True, 
                          write_grads=True, write_images=True, embeddings_freq=0, 
                          embeddings_layer_names=None, embeddings_metadata=None, 
                          embeddings_data=None, update_freq='epoch')

write_time = time.strftime("%H"+"%M")

# %% [markdown]
# ---

# %%
# !/opt/bin/nvidia-smi
# Out:
# Sat Dec  8 19:10:32 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 396.44                 Driver Version: 396.44                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Training

# %%
hist = model.fit_generator(my_generator(x_train, y_train, batch_size),
                           steps_per_epoch = 200,
                           validation_data = (x_test, y_test),
                           epochs=epochs, verbose=1,
                           callbacks = [weight_saver, annealer, tensorboard])
# Out:
# Epoch 1/50
# 200/200 [==============================] - 146s 730ms/step - loss: 0.2260 - dice_coef: 0.7740 - val_loss: 0.0943 - val_dice_coef: 0.9057
# Epoch 2/50
# 200/200 [==============================] - 126s 628ms/step - loss: 0.0995 - dice_coef: 0.9005 - val_loss: 0.1169 - val_dice_coef: 0.8831
# Epoch 3/50
# 200/200 [==============================] - 126s 631ms/step - loss: 0.0756 - dice_coef: 0.9244 - val_loss: 0.0792 - val_dice_coef: 0.9208
# Epoch 4/50
# 200/200 [==============================] - 126s 630ms/step - loss: 0.0634 - dice_coef: 0.9366 - val_loss: 0.0634 - val_dice_coef: 0.9366
# Epoch 5/50
# 200/200 [==============================] - 126s 629ms/step - loss: 0.0578 - dice_coef: 0.9422 - val_loss: 0.0569 - val_dice_coef: 0.9431
# Epoch 6/50
# 200/200 [==============================] - 126s 630ms/step - loss: 0.0522 - dice_coef: 0.9478 - val_loss: 0.0502 - val_dice_coef: 0.9498
# Epoch 7/50
# 200/200 [==============================] - 126s 631ms/step - loss: 0.0498 - dice_coef: 0.9502 - val_loss: 0.0619 - val_dice_coef: 0.9381
# Epoch 8/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0472 - dice_coef: 0.9528 - val_loss: 0.0638 - val_dice_coef: 0.9362
# Epoch 9/50
# 200/200 [==============================] - 127s 634ms/step - loss: 0.0451 - dice_coef: 0.9549 - val_loss: 0.0624 - val_dice_coef: 0.9376
# Epoch 10/50
# 200/200 [==============================] - 127s 636ms/step - loss: 0.0439 - dice_coef: 0.9561 - val_loss: 0.0546 - val_dice_coef: 0.9454
# Epoch 11/50
# 200/200 [==============================] - 127s 634ms/step - loss: 0.0433 - dice_coef: 0.9567 - val_loss: 0.0659 - val_dice_coef: 0.9341
# Epoch 12/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0424 - dice_coef: 0.9576 - val_loss: 0.0586 - val_dice_coef: 0.9414
# Epoch 13/50
# 200/200 [==============================] - 126s 632ms/step - loss: 0.0412 - dice_coef: 0.9588 - val_loss: 0.0613 - val_dice_coef: 0.9387
# Epoch 14/50
# 200/200 [==============================] - 126s 632ms/step - loss: 0.0411 - dice_coef: 0.9589 - val_loss: 0.0579 - val_dice_coef: 0.9421
# Epoch 15/50
# 200/200 [==============================] - 126s 632ms/step - loss: 0.0402 - dice_coef: 0.9598 - val_loss: 0.0623 - val_dice_coef: 0.9377
# Epoch 16/50
# 200/200 [==============================] - 126s 632ms/step - loss: 0.0401 - dice_coef: 0.9599 - val_loss: 0.0606 - val_dice_coef: 0.9394
# Epoch 17/50
# 200/200 [==============================] - 126s 632ms/step - loss: 0.0400 - dice_coef: 0.9600 - val_loss: 0.0623 - val_dice_coef: 0.9377
# Epoch 18/50
# 200/200 [==============================] - 126s 632ms/step - loss: 0.0395 - dice_coef: 0.9605 - val_loss: 0.0576 - val_dice_coef: 0.9424
# Epoch 19/50
# 200/200 [==============================] - 128s 639ms/step - loss: 0.0393 - dice_coef: 0.9607 - val_loss: 0.0577 - val_dice_coef: 0.9423
# Epoch 20/50
# 200/200 [==============================] - 126s 631ms/step - loss: 0.0391 - dice_coef: 0.9609 - val_loss: 0.0688 - val_dice_coef: 0.9312
# Epoch 21/50
# 200/200 [==============================] - 127s 634ms/step - loss: 0.0392 - dice_coef: 0.9608 - val_loss: 0.0584 - val_dice_coef: 0.9416
# Epoch 22/50
# 200/200 [==============================] - 127s 634ms/step - loss: 0.0389 - dice_coef: 0.9611 - val_loss: 0.0598 - val_dice_coef: 0.9402
# Epoch 23/50
# 200/200 [==============================] - 126s 632ms/step - loss: 0.0387 - dice_coef: 0.9613 - val_loss: 0.0580 - val_dice_coef: 0.9420
# Epoch 24/50
# 200/200 [==============================] - 126s 632ms/step - loss: 0.0389 - dice_coef: 0.9611 - val_loss: 0.0618 - val_dice_coef: 0.9382
# Epoch 25/50
# 200/200 [==============================] - 126s 631ms/step - loss: 0.0386 - dice_coef: 0.9614 - val_loss: 0.0615 - val_dice_coef: 0.9385
# Epoch 26/50
# 200/200 [==============================] - 126s 632ms/step - loss: 0.0385 - dice_coef: 0.9615 - val_loss: 0.0590 - val_dice_coef: 0.9410
# Epoch 27/50
# 200/200 [==============================] - 126s 632ms/step - loss: 0.0384 - dice_coef: 0.9616 - val_loss: 0.0577 - val_dice_coef: 0.9423
# Epoch 28/50
# 200/200 [==============================] - 127s 634ms/step - loss: 0.0387 - dice_coef: 0.9613 - val_loss: 0.0581 - val_dice_coef: 0.9419
# Epoch 29/50
# 200/200 [==============================] - 127s 634ms/step - loss: 0.0385 - dice_coef: 0.9615 - val_loss: 0.0598 - val_dice_coef: 0.9402
# Epoch 30/50
# 200/200 [==============================] - 126s 632ms/step - loss: 0.0385 - dice_coef: 0.9615 - val_loss: 0.0576 - val_dice_coef: 0.9424
# Epoch 31/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0390 - dice_coef: 0.9610 - val_loss: 0.0580 - val_dice_coef: 0.9420
# Epoch 32/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0382 - dice_coef: 0.9618 - val_loss: 0.0579 - val_dice_coef: 0.9421
# Epoch 33/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0384 - dice_coef: 0.9616 - val_loss: 0.0576 - val_dice_coef: 0.9424
# Epoch 34/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0385 - dice_coef: 0.9615 - val_loss: 0.0582 - val_dice_coef: 0.9418
# Epoch 35/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0384 - dice_coef: 0.9616 - val_loss: 0.0582 - val_dice_coef: 0.9418
# Epoch 36/50
# 200/200 [==============================] - 126s 632ms/step - loss: 0.0384 - dice_coef: 0.9616 - val_loss: 0.0590 - val_dice_coef: 0.9410
# Epoch 37/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0385 - dice_coef: 0.9615 - val_loss: 0.0582 - val_dice_coef: 0.9418
# Epoch 38/50
# 200/200 [==============================] - 127s 635ms/step - loss: 0.0385 - dice_coef: 0.9615 - val_loss: 0.0583 - val_dice_coef: 0.9417
# Epoch 39/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0383 - dice_coef: 0.9617 - val_loss: 0.0584 - val_dice_coef: 0.9416
# Epoch 40/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0386 - dice_coef: 0.9614 - val_loss: 0.0581 - val_dice_coef: 0.9419
# Epoch 41/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0384 - dice_coef: 0.9616 - val_loss: 0.0577 - val_dice_coef: 0.9423
# Epoch 42/50
# 200/200 [==============================] - 127s 634ms/step - loss: 0.0384 - dice_coef: 0.9616 - val_loss: 0.0579 - val_dice_coef: 0.9421
# Epoch 43/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0384 - dice_coef: 0.9616 - val_loss: 0.0579 - val_dice_coef: 0.9421
# Epoch 44/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0386 - dice_coef: 0.9614 - val_loss: 0.0579 - val_dice_coef: 0.9421
# Epoch 45/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0383 - dice_coef: 0.9617 - val_loss: 0.0578 - val_dice_coef: 0.9422
# Epoch 46/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0384 - dice_coef: 0.9616 - val_loss: 0.0581 - val_dice_coef: 0.9419
# Epoch 47/50
# 200/200 [==============================] - 127s 635ms/step - loss: 0.0386 - dice_coef: 0.9614 - val_loss: 0.0581 - val_dice_coef: 0.9419
# Epoch 48/50
# 200/200 [==============================] - 127s 634ms/step - loss: 0.0385 - dice_coef: 0.9615 - val_loss: 0.0581 - val_dice_coef: 0.9419
# Epoch 49/50
# 200/200 [==============================] - 127s 636ms/step - loss: 0.0384 - dice_coef: 0.9616 - val_loss: 0.0581 - val_dice_coef: 0.9419
# Epoch 50/50
# 200/200 [==============================] - 127s 633ms/step - loss: 0.0382 - dice_coef: 0.9618 - val_loss: 0.0581 - val_dice_coef: 0.9419

# %%
model.load_weights('seg.h5')

# %% [markdown]
# ---

# %% [markdown]
# # Results

# %% [markdown]
# Learning Rate Plot

# %%
plt.plot(hist.history['lr'], color='b')
plt.xlabel("epochs")
plt.ylabel("Learning Rate")
plt.grid(linestyle='dotted')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# Loss and Dice Coefficient Plot

# %%
plt.plot(hist.history['loss'], color='b', label='Training')
plt.plot(hist.history['val_loss'], color='r', label='Validation')
plt.legend(loc='upper right')
plt.xlabel("epochs")
plt.ylabel("Loss")
plt.grid(linestyle='dotted')
plt.show()

plt.plot(hist.history['dice_coef'], color='b', label='Training')
plt.plot(hist.history['val_dice_coef'], color='r', label='Validation')
plt.xlabel("epochs")
plt.ylabel("Dice Coefficient")
plt.legend(loc='lower right')
plt.grid(linestyle='dotted')
plt.show()

# %%
# To run tensorboard
print('To view tensorboard, put this in your command line: \n tensorboard --log=logs/{}/'.format(write_time))
# Out:
# To view tensorboard, put this in your command line:
#  tensorboard --log=logs/1910/

# %%
# !rm -rf ngrok-stable-linux-amd64.zip
# !rm -rf ngrok
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
#!rm -f log/*   # Delete this if you want to keep the logs of the old runs
LOG_DIR = 'logs/{}'.format(write_time)
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
get_ipython().system_raw('./ngrok http 6006 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# --2018-12-08 21:01:18--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.22.145.207, 52.203.53.176, 52.207.111.186, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.22.145.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5363700 (5.1M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]   5.11M  19.1MB/s    in 0.3s
#
# 2018-12-08 21:01:18 (19.1 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [5363700/5363700]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok
# https://b43d770d.ngrok.io

# %% [markdown]
# ---

# %% [markdown]
# # Prediction

# %%
y_pred = model.predict(x_test)
for i in range(10):
    fig, ax = plt.subplots(1,3,figsize=(12,6))
    ax[0].imshow(x_test[i,:,:,0], cmap='gray')
    ax[1].imshow(y_test[i,:,:,0], cmap='viridis')
    ax[2].imshow(y_pred[i,:,:,0], cmap='viridis')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Appendix

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   36928       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  147584      conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 128)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 256)    295168      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 256)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 256)  590080      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 384)  0           conv2d_8[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 256)  884992      concatenate_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 256)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 256)  590080      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 320)  0           conv2d_6[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 256)  737536      concatenate_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 256)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 128)  295040      up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 192)  0           conv2d_4[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 128)  221312      concatenate_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 128 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 64) 73792       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 96) 0           conv2d_2[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 64) 55360       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 1)  577         conv2d_21[0][0]
# ==================================================================================================
# Total params: 5,468,897
# Trainable params: 5,468,897
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Reference

# %% [markdown]
# *   https://www.kaggle.com/toregil/a-lung-u-net-in-keras
# *   https://github.com/jocicmarko/ultrasound-nerve-segmentation
